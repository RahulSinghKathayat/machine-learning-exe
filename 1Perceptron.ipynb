# %% [markdown]
# Building Single Layer Perceptron----------->

# %%
import numpy as np
import pandas as  pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dataset = pd.read_csv("C://Users//NITRO V//Downloads//archive//online_course_engagement_data.csv")

# %%
dataset
modified = dataset.drop("CourseCategory", axis=1)
modified
# Out:
#       UserID  TimeSpentOnCourse  NumberOfVideosWatched  NumberOfQuizzesTaken  \
# 0       5618          29.979719                     17                     3
# 1       4326          27.802640                      1                     5
# 2       5849          86.820485                     14                     2
# 3       4992          35.038427                     17                    10
# 4       3866          92.490647                     16                     0
# ...      ...                ...                    ...                   ...
# 8995    8757          37.445225                     14                     4
# 8996     894          48.631443                      7                     7
# 8997    6323          38.212512                      3                     3
# 8998    3652          70.048665                     13                    10
# 8999    5595          93.589781                      7                     5
#
# ...

# %%
pip install fsspec
# Out:
# ...
#    ---------------------------------------- 0.0/177.6 kB ? eta -:--:--
#    --------------------------------------- 177.6/177.6 kB 11.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
modified.head(3)
# Out:
#    UserID  TimeSpentOnCourse  NumberOfVideosWatched  NumberOfQuizzesTaken  \
# 0    5618          29.979719                     17                     3
# 1    4326          27.802640                      1                     5
# 2    5849          86.820485                     14                     2
#
#    QuizScores  CompletionRate  DeviceType  CourseCompletion
# 0   50.365656       20.860773           1                 0
# 1   62.615970       65.632415           1                 0
# 2   78.458962       63.812007           1                 1

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x = "UserID", y = "NumberOfVideosWatched", data = modified, hue = "CourseCompletion")
plt.show()

# %%
x = modified.iloc[:,:-1]
y = modified["CourseCompletion"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .20, random_state= 30)

# %%
from sklearn.linear_model import Perceptron

# %%
pr = Perceptron(alpha=0.1)

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
# x_train_encoded = lb.fit_transform(x_train)
y_train_encoded = lb.fit_transform(y_train)
# pr.fit(x_train,y_train_encoded)

# %%
pr.fit(x_train,y_train_encoded)
# Out:
# Perceptron(alpha=0.1)

# %%
pr.score(x_train,y_train_encoded)
# Out:
# 0.6079166666666667

# %%
pr.score(x_test,y_test)
# Out:
# 0.6022222222222222

# %% [markdown]
# ONGOING------------->

# %%
# Assuming features 0 and 1 for visualization and features 4, 5, 6 need filler values
plt.figure(figsize=(4,4))
filler_feature_values = {2: 0.5, 3: 1.0, 4: 2.0, 5: 3.0, 6: 4.0}  # Constant values for features 2, 3, 4, 5, and 6

plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=pr, feature_index=(0, 1), filler_feature_values=filler_feature_values)
plt.show()
# Out:
# c:\Users\NITRO V\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
